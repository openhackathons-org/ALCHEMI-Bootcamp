# %% [markdown]
# # Part 2: ALCHEMI Toolkit Sandbox
#
# Interactive environment for exploring the [NVIDIA ALCHEMI Toolkit](https://github.com/NVIDIA/nvalchemi-toolkit) Python library.
#
# This notebook is currently a smoke test, not the synchronized toolkit version of the Part 1 AdsorbML tutorial. The Docker image pins `nvalchemi-toolkit` through `NVALCHEMI_TOOLKIT_REF`; record that value before comparing notebook results across environments.

# %%
import os
from importlib.metadata import version, PackageNotFoundError

import nvalchemi

print(f"nvalchemi module: {nvalchemi.__file__}")
print(f"NVALCHEMI_TOOLKIT_REF: {os.environ.get('NVALCHEMI_TOOLKIT_REF', 'not set')}")
try:
    print(f"nvalchemi-toolkit version: {version('nvalchemi-toolkit')}")
except PackageNotFoundError:
    print("nvalchemi-toolkit package metadata not found")
